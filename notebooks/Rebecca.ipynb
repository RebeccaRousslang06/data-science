# %% [markdown]
# <a href="https://colab.research.google.com/github/RebeccaRousslang06/data-science/blob/main/notebooks/Rebecca.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("hello")
# Out:
# hello

# %%
test_variable = "one"

# %%
print(test_variable)
# Out:
# one

# %% [markdown]
# ## Example Heading
#
# Here's a block of text

# %%
# %pip install pandas

# %%
import pandas as pd

# %%
from google.cloud import bigquery

# %%
# Create a "Client" object
client = bigquery.Client()

# %%
# Construct a reference to the "hacker_news" dataset
dataset_ref = client.dataset("hacker_news", project="bigquery-public-data")

# API request - fetch the dataset
dataset = client.get_dataset(dataset_ref)
# Out:
# ---------------------------------------------------------------------------
# RefreshError                              Traceback (most recent call last)
# /tmp/ipython-input-31446014.py in <cell line: 0>()
#       3
#       4 # API request - fetch the dataset
# ----> 5 dataset = client.get_dataset(dataset_ref)
#
# /usr/local/lib/python3.12/dist-packages/google/cloud/bigquery/client.py in get_dataset(self, dataset_ref, retry, timeout, dataset_view)
#     917
#     918         span_attributes = {"path": path}
# --> 919         api_response = self._call_api(
#     920             retry,
#     921             span_name="BigQuery.getDataset",
#
# /usr/local/lib/python3.12/dist-packages/google/cloud/bigquery/client.py in _call_api(self, retry, span_name, span_attributes, job_ref, headers, **kwargs)
#     859                 name=span_name, attributes=span_attributes, client=self, job_ref=job_ref
#     860             ):
# --> 861                 return call()
#     862
# ...
